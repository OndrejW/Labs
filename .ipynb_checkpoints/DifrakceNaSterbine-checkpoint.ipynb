# %% [markdown]
# <b><center style="color: red">Pro správnou funkčnost všech widgetů klikněte na Kernel>Restart & Run all</center></b>
# # Difrakce na štěrbině

# %% [markdown]
# Fyziku dlouho provázela debata, jestli má světlo povahu částicovou nebo vlnovou. Teorie vybudovaná James Clark Maxwellem(tzv. Maxwellovy rovnice), světlo považuje za elektro-magnetické vlnění. Tyto předpovědi byly později potvrzené experimentálně sérií pokusů provedených Heinrichem Hertzem. Na přelomu 19. a 20. století většina fyziků věřila, že "vše důležité" bylo již objeveno. Ovšem v roce 1905 přišel Albert Einstein s koncepcí kvantování elektromagnetického vlnění, což položilo základy kvantové mechaniky a vysvětlilo jeden z tehdy posledních problémů fyziky: záření černého tělesa.
#
# V tomto cvičení se budeme věnovat vlnové povaze světla a to konkrétně difrakčním jevům na apertuře.

# %% [markdown]
# ## Zadání
#
# 1. Předpovězte vhodné vzdálenosti apertury od stínítka
# 2. Vytvořte dle návodu níže aperturu a pořiďte její difrakční obrazec.
# 3. Na základě vyhodnocení difrakčního obrazce stanovte velikost vytvořené apertury.
# 4. Porovnejte získaná data se simulací - využijte interaktivní modul níže.
# 5. Zhodnoťte výsledky experimentu a simulace. Je-li třeba, diskutujte neshody mezi dosaženými výsledky.

# %% [markdown]
# ## Teorie
# Šíření světla můžeme popsat pomocí tzv. Hyugensova principu. Tento princip říká, že každý bod na vlnoploše šířeného světla se stává novým zdrojem šíření.

# %% [markdown]
# ![hyugens.png](attachment:hyugens.png)

# %% [markdown]
# Tento princip je názorně ilustrován na následujícím videu.

# %%
from IPython.display import YouTubeVideo
YouTubeVideo('ANsHXbIoA6U')

# %% [markdown]
# Nejenže tento princip dává určitý vhled do problematiky šíření vln (lze uplatnit obecně na jakékoliv vlnění, třeba i na vodní hladině), ale může i sloužit pro odvození vztahů

# %%
from IPython.display import YouTubeVideo
YouTubeVideo('7CmbItRjM-Y')

# %% [markdown]
# ### Poněkud rigoróznější vhled do problematiky difrakce dává následující text
# Difrakce (neboli ohyb vlnění) je jev, při kterém se světlo odchyluje od přímočarého šíření jinak než odrazem nebo lomem. Jinak řečeno, difrakce pojmenovává jevy, které nastanou, když se vlnění potká s překážkou nebo aperturou - vlnění se na okrajích překážky ohýbá a šíří se i v směrech, které se pro něj z hlediska geometrie jeví jako nedosažitelné. Snad nejběžnějším důsledkem difrakce je, že někoho slyšíme mluvit i když stojí za rohem - zvuková vlna se nepropaguje jenom v dopředném směru, ale na zdech difraktuje (ohýbá se) i směrem k nám.
#
# Optika rozlišuje Fresnelovy a Fraunhoferovy difrakční jevy. V případě Fresnelovy difrakce je pro nás zajímavá intenzita světla jako funkce polohy v rovině pozorování (konečně vzdálené od roviny difrakčního prvku). Fraunhoferova difrakce je v mnoha pojetích zvláštním případem Fresnelovy difrakce - popisuje intenzitu záření jako funkci směru, tj. v rovině pozorování nekonečně vzdálené od difrakčního prvku.
#
# Fraunhoferova difrakce popsána Fourierovou transformací funkce $\psi$, která charakterizuje vlnění na zadní straně rovinného difrakčního stínitka. Uvažujeme-li osvětlení jako rovinnou vlnu:
#
# $\psi \sim \mathrm{exp}[-ik \vec{n_0} \cdot \vec{r}]$
#
# a vektor $\vec{n_0}=(0,0,1)$ zodpovídající kolmému dopadu na stínitko, pak má vlna v rovině stínitka konstantní hodnotu:
#
# $\psi(x_M, y_M)=t(x_M,y_M)$,
#
# kde $t(x_M,y_M)$ je funkce propustnosti stínitka. Fraunhoferova difrakce je v takovém případě charakterizována:
#
# $ \psi(x_M, y_M) = C \iint_{-\infty}^{\infty} t(x_M,y_M)\,\mathrm{exp}[-ik(n_x x_M + n_y y_M]\, \mathrm{d}x_M \mathrm{d}y_M$
#
# Uvážíme-li stínítko se štěrbinou dokonale propustnou pro $x_M=\frac{-w}{2}$ až $x_M=\frac{w}{2}$ a dokonale nepropustnou všude jinde, redukuje se řešení integrálu na následující vlnovou funkci:
#
# $\psi(n_x,n_y)=C \frac{2\pi}{k} a \frac{\mathrm{sin}(kn_x w/2)}{kn_x w/2} \delta(n_y)$,
#
# Pomocí vztahů $k=2\pi/\lambda$ a $n_x\doteq L$ můžeme intenzitu světla (danou kvadrátem vlnové funkce) psát jako:
#
# $I(x) \sim \mathrm{sinc} \frac{\pi w x}{\lambda L}$

# %%
from __future__ import print_function
from ipywidgets import interact, interactive, fixed, interact_manual
import ipywidgets as widgets
import numpy as np
import matplotlib.pyplot as plt
plt.rcParams.update({'font.size': 12})


@interact(usedlambda=widgets.IntSlider(min=400, max=700, step=10, value=630), w=widgets.IntSlider(min=1, max=20, step=1, value=5), L=widgets.IntSlider(min=10, max=1000, step=1, value=100))
def intensity(usedlambda, w, L):
    usedlambda = usedlambda*1e-9
    w = w*1e-6
    L = L*1e-3
    x = np.linspace(0,40e-3,200)
    I = (np.sinc(np.pi*w*x/(usedlambda*L)))**2
    plt.plot(x*1e3, I);
    plt.xlabel('x (mm)');
    plt.ylabel('Norm. intenzita ()');
    plt.show()
    return();
# Out:
# interactive(children=(IntSlider(value=630, description='usedlambda', max=700, min=400, step=10), IntSlider(val…

# %% [markdown]
# Stejné vlastnoti interferenčních obrazců, které jste si právě vyzkoušeli v předcházejícím widgetu, jsou demonstrovány v následujícím videu z MIT.

# %%
from IPython.display import YouTubeVideo
YouTubeVideo('9D8cPrEAGyc')

# %% [markdown]
# Tento vztah popisuje vývoj intenzity v závislosti na vzdálenosti středu difrakčního obrazce. Zadáním toho protokolu je pouze zjistit velikost vyrobené apertury, proto můžeme využít vlastnosti minima funkce intenzity a vyvodit vztah pro šířku štěrbiny:
#
# $w = \frac{m L \lambda}{x}$
#
# Ze vztahu plyne, že pro výpočet potřebujeme znát vlnovou délku světla $\lambda$, řád minima $m$, jeho vzdálenost od středu obrazce $x$ a vzdálenost apertury od stínítka $L$.

# %% [markdown]
# ## Příprava
#
# V následujícím úkolu se pokusíme odhadnout optimální vzdálenost apertury od stínítka. Je potřeba snažit se dát stínítko co nejdále, nebo naopak co nejblíž. Existuje optimální vzdálenost? Využijeme k tomu teorii vybudovanou v předchozích částech sešitu. Můžete použít jakýkoliv programovací jazyk, nebo jen doupravit následující kód v Pythonu.

# %%
def vzdalenostMin(vln_delka, m, w, L):
    #Tuto funkci doplnte tak, aby pocitala vzdalenosti minim
    vzdMin = 
    return(vzdMin)

#Zde vhodne zvolte meze a pocet bodu. Rozměry zadávejte v m
start =
stop =
pocetBodu =
L = np.linspace(start, stop, pocetBodu) 

VzdalenostminVsL = vzdalenostMin(vln_delka = 630e-9, m = 1, w = 10e-6,L = L) # vlnova delka v metrech, první řád, odhadovaná šířka štěrbiny

plt.plot(L, VzdalenostminVsL);
plt.xlabel('L (m)');
plt.ylabel('x (m)');
plt.show()
# Out:
#   File "<ipython-input-5-26cae9a205a4>", line 3
#     vzdMin =
#              ^
# SyntaxError: invalid syntax

# %% [markdown]
# ## Experiment

# %% [markdown]
# ### Výroba apertury a pořízení snímku difrakčního obrazce
# Budeme potřebovat:
#  - hliníková folie na pečení (alobal), ca. ($2\times2$) cm$^2$
#  - ostrý hrot - nejlépe jehla, špendlík, nebo kružítko
#  - lepící páska
#  - zdroj záření - ideálně mobilní telefon se zabudovanou svítilnou, nebo svítilnu a fotoaparát
#  - pravítko nebo jiný předmět o definované velikosti
#  - program pro obrazovou analýzu (např. ImageJ)
#
# Postup:
# 1. Do kousku hliníkové fólie uděláme pomocí ostrého hrotu malou díru. (*Tip: položte fólii na svůj ukazovák a dělejte díru do fólie na ukazováčku - protože se nechcete moc píchnout, díra bude skutečně malá. Méně sebepoškozující je položit fólii na desku a udělat dírku do stolu.*)
# 2. Hliníkovou fólii s aperturou umístíme na telefon tak, aby apertura byla přesně nad zdrojem světla. Okraje fólie připevníme lepící páskou a ujistíme se, že v místě nad zdrojem světla folie dobře přiléhá - v opačném případě může dojít k odrazu světla na telefonu a fólii, čím vznikne parazitní záření. Velký kus alobalu by měl blokovat většinu tohoto záření, a to i takového, které neprochází aperturou. Také se ujistíme, že fólie neblokuje kameru telefonu.
#
# 3. V temné místnosti pořídíme snímek difrakčního obrazce. Na snímek taky zaznamenáme předmět o známé velikosti, např. pravítko, jak vidět na schematu. Jak je známo z teorie, je nutné abychom znali vzdálenost apertury od stínitka - zdi. Proto si tento údaj zapíšeme.
#  - Pozor, před pořízením snímku se musíme ujistit, že kamera, zdroj s aperturou a stínítko jsou všechny navzájem paralelní - případné odchylky v náklonu jedné ze součástí by mohly způsobit nepřesnosti při vyhodnocování dat.

# %% [markdown]
# ![DifrakceNaSterbine-schema.ipynb.png](attachment:DifrakceNaSterbine-schema.ipynb.png)

# %% [markdown]
#  ### Zpracování dat
#
# 1. Fotku difrakčního obrazce nahrajeme do programu ImageJ.
# 2. Jako první si naměříme data pro určení konstanty pro převod pixelů na délku v rovině stínítka (neuvažujeme optické vady a různá zkreslení). Změříme tedy počet pixelů zodpovídajících přesně danému rozměru předmětu, který jsme na snímku zaznamenali spolu s difrakčním obrazcem.
# 3. Ve druhém kroku rozdělíme obraz na tři vlnové délky (RGB kanály) a pro každý kanál extrahujeme intenzitu podél čary od středu a naměříme polohu minim v pixelech. Hodnoty pomocí převodné konstanty přepočítáme na vzdálenosti minim od středu obrazce v metrech. Pro toto zpracování můžeme použít konzoli Pythonu níže, popřípadě jiný programovací jazyk, nebo tabulkový procesor (Excel, OpenOffice Calc).
# 4. Dosazením získaných poloh intenzitních minim, vzdálenosti apertury od stínitka a vlnové délky zodpovídající jednému ze tří barevných kanálů do rovnice pro výpočet intenzity určíme průmer apertury _w_.

# %%
pxNaM = #doplnte konstantu prevodu v jednotkach pixel/metr

usedLambda = 630e-9 # vlnova delka cervenho svetla v nm
# Namerene vzdalenosti v pixelech
vzdalenost1minPx = 
vzdalenost2minPx = 
vzdalenost3minPx = 
# atd...

def prevodPxNaM(px, pxNaM):
    vzdalenostVm =  #Zde doplnte vzorec pro prevod
    return(vzdalenostVm)

#Prevod na m
vzdalenost1minM = prevodPxNaM(vzdalenost1minPx, pxNaM)
vzdalenost2minM = prevodPxNaM(vzdalenost2minPx, pxNaM)
vzdalenost3minM = prevodPxNaM(vzdalenost3minPx, pxNaM)
# atd...


# Vypsani
print('Prvni minimum je ve vzdalenosti: ',vzdalenost1minM*1e3,'mm')
print('Druhe minimum je ve vzdalenosti: ',vzdalenost2minM*1e3,'mm')
print('Treti minimum je ve vzdalenosti: ',vzdalenost3minM*1e3,'mm')
# atd...

# Vypocet velikosti sterbiny
L = #Vzdalenost sterbiny od stinitka (m)

print('Vysledky pro cervenou')
w1 = 1*usedLambda*L/vzdalenost1minM #prvni maximum
print('Sirka sterbiny pri vyhodnoceni prvniho minima je: ',w1*1e6,' um')
w2 = 2*usedLambda*L/vzdalenost2minM #druhe maximum
print('Sirka sterbiny pri vyhodnoceni druheho minima je: ',w2*1e6,' um')
w3 = 3*usedLambda*L/vzdalenost3minM #druhe maximum
print('Sirka sterbiny pri vyhodnoceni druheho minima je: ',w3*1e6,' um')
# atd...
